# %% [markdown]
# # Solve surface volatiles according to outgassing+chemistry

# %%
import sys
sys.path.append("..")
from calliope.solve import *
from calliope.structure import calculate_mantle_mass
from calliope.constants import R_earth, const_G, M_earth

from copy import deepcopy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Set up initial options dict

# %%
OPTIONS = {}

OPTIONS['Phi_global'] = 1.0
OPTIONS['T_magma'] = 2500.0

OPTIONS['radius'] = R_earth * 1.875
OPTIONS['mass']   = M_earth * 7.99
OPTIONS['gravity'] = const_G * OPTIONS['mass'] / (OPTIONS['radius']**2)
OPTIONS['hydrogen_earth_oceans'] = 8.0
OPTIONS['CH_ratio'] = 1.0
OPTIONS['fO2_shift_IW'] = 0.0
OPTIONS['nitrogen_ppmw'] = 4.0
OPTIONS['sulfur_ppmw'] = 300.0
OPTIONS['planet_coresize'] = 0.5

solvevol_vols = ['H2O', 'CO2', 'N2', 'H2', 'CO', 'CH4', 'S2', 'SO2', 'H2S']
for v in solvevol_vols:
    OPTIONS[v+"_included"] = 0
    OPTIONS[v+"_initial_bar"] = 0.0

OPTIONS["H2O_included"] = 1
OPTIONS["CO2_included"] = 1
OPTIONS["N2_included"]  = 1
OPTIONS["S2_included"]  = 1

OPTIONS["H2_included"]  = 1
OPTIONS["CO_included"]  = 1
OPTIONS["CH4_included"] = 1
OPTIONS["SO2_included"] = 1
OPTIONS["H2S_included"] = 1

# OPTIONS["H2O_initial_bar"] = 1.0
# OPTIONS["CO2_initial_bar"] = 0.0
# OPTIONS["N2_initial_bar"]  = 0.0

print("Gravity = %.3f m.s-2" % OPTIONS["gravity"])
# Out:
# Gravity = 22.569 m.s-2

# %% [markdown]
# ### Calculate total amount of each element in the system

# %%
OPTIONS["M_mantle"] = calculate_mantle_mass(OPTIONS["radius"], OPTIONS["mass"], OPTIONS["planet_coresize"])
BACKUP_options = deepcopy(OPTIONS)

# %%
solvevol_target = get_target_from_params(OPTIONS)
# solvevol_target = get_target_from_pressures(OPTIONS)

print("Targets:")
print(solvevol_target)
# Out:
# Targets:
# {'H': 1.24e+21, 'C': 1.24e+21, 'N': 1.5241577798741547e+20, 'S': 1.1431183349056161e+22}

# %% [markdown]
# ### Solve for equilibrium atmospheric partial pressures, etc.

# %%
p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)

print(p_d)

p_bar = {}
for v in volatile_species:
    p_bar[v] = p_d[v+"_bar"]

mubar = 0.0
ptot = 0.0
print("Partial pressures")
for v in solvevol_vols:
    print("    %s : %.3f bar"%(v, p_bar[v]))
    ptot += p_bar[v]
    mubar += p_bar[v]*molar_mass[v]
mubar /= ptot

print("mubar =",mubar)
print("ptot = %.3f bar"%ptot)

m_d = {}
for v in solvevol_vols:
    m_d[v] = p_bar[v]*1.0e5 * 4 * 3.14 * (molar_mass[v]/mubar) * OPTIONS["radius"]**2.0 / OPTIONS["gravity"]

# print(solvevol_atmosphere_mass(p_bar, OPTIONS))

print(" ")
print(m_d)

H_kg = (2*m_d["H2O"]/molar_mass["H2O"] + 2*m_d["H2"]/molar_mass["H2"] + 4*m_d["CH4"]/molar_mass["CH4"]) *molar_mass['H']
C_kg = (m_d["CO2"]/molar_mass["CO2"] + m_d["CO"]/molar_mass["CO"] + m_d["CH4"]/molar_mass["CH4"]) * molar_mass['C']
N_kg = m_d["N2"]
S_kg = m_d["S2"]

print(H_kg, C_kg, N_kg, S_kg)
# Out:
# {'M_atm': 2.099186656210836e+21, 'P_surf': 267.17772771592007, 'H2O_bar': 0.30774171101852543, 'H2O_kg_atm': 1.4986114838628288e+18, 'H2O_kg_liquid': 1.1076292218586248e+22, 'H2O_kg_solid': 0.0, 'H2O_kg_total': 1.1077790830070111e+22, 'CO2_bar': 18.829616516224043, 'CO2_kg_atm': 2.240033532091032e+20, 'CO2_kg_liquid': 3.2712488404115764e+20, 'CO2_kg_solid': 0.0, 'CO2_kg_total': 5.511282372502608e+20, 'H2_bar': 0.6213537738555504, 'H2_kg_atm': 3.385831119058288e+17, 'H2_kg_liquid': 0.0, 'H2_kg_solid': 0.0, 'H2_kg_total': 3.385831119058288e+17, 'CH4_bar': 8.559215602020457e-07, 'CH4_kg_atm': 3711077344575.5127, 'CH4_kg_liquid': 451308443089.8503, 'CH4_kg_solid': 0.0, 'CH4_kg_total': 4162385787665.363, 'CO_bar': 230.95623628255294, 'CO_kg_atm': 1.748656385378026e+21, 'CO_kg_liquid': 7.922960278221825e+20, 'CO_kg_solid': 0.0, 'CO_kg_total': 2.5409524132002084e+21, 'N2_bar': 16.45834247412192, 'N2_kg_atm': 1.2463008612409829e+20, 'N2_kg_liquid': 2.7785691863317234e+19, 'N2_kg_solid': 0.0, 'N2_kg_total': 1.524157779874155e+20, 'S2_bar': 9.936870614861492e-05, 'S2_kg_atm': 1721747021088905.2, 'S2_kg_liquid': 1.143114490518766e+22, 'S2_kg_solid': 0.0, 'S2_kg_total': 1.1431146626934683e+22, 'SO2_bar': 0.0022144583300586513, 'SO2_kg_atm': 3.834924317911619e+16, 'SO2_kg_liquid': 0.0, 'SO2_kg_solid': 0.0, 'SO2_kg_total': 3.834924317911619e+16, 'H2S_bar': 0.0021222751892982393, 'H2S_kg_atm': 1.9562202562641964e+16, 'H2S_kg_liquid': 0.0, 'H2S_kg_solid': 0.0, 'H2S_kg_total': 1.9562202562641964e+16, 'H2O_vmr': 0.0011518239699445888, 'CO2_vmr': 0.07047599617377111, 'H2_vmr': 0.0023256196508872635, 'CH4_vmr': 3.2035662834595054e-09, 'CO_vmr': 0.8644292256580606, 'N2_vmr': 0.06160072778080309, 'S2_vmr': 3.7191987145825977e-07, 'SO2_vmr': 8.28833431959269e-06, 'H2S_vmr': 7.943308775927512e-06, 'H_kg_atm': 5.074628474478774e+17, 'H_kg_liquid': 1.2394925371525528e+21, 'H_kg_solid': 0.0, 'H_kg_total': 1.2400000000000008e+21, 'C_kg_atm': 8.109772692665514e+20, 'C_kg_liquid': 4.2902273073344846e+20, 'C_kg_solid': 0.0, 'C_kg_total': 1.24e+21, 'N_kg_atm': 1.2463008612409829e+20, 'N_kg_liquid': 2.7785691863317234e+19, 'N_kg_solid': 0.0, 'N_kg_total': 1.524157779874155e+20, 'S_kg_atm': 3.844383806202803e+16, 'S_kg_liquid': 1.143114490518766e+22, 'S_kg_solid': 0.0, 'S_kg_total': 1.1431183349025723e+22, 'O_kg_atm': 1.1630274220081007e+21, 'O_kg_liquid': 1.052701827830658e+22, 'O_kg_solid': 0.0, 'O_kg_total': 1.169004570031468e+22, 'atm_kg_per_mol': 0.029066258350517196, 'H2O_mol_atm': 8.318557823485556e+19, 'H2O_mol_solid': 0.0, 'H2O_mol_liquid': 6.148276473408266e+23, 'H2O_mol_total': 6.149108329190616e+23, 'CO2_mol_atm': 5.089828520997573e+21, 'CO2_mol_solid': 0.0, 'CO2_mol_liquid': 7.432967144766135e+21, 'CO2_mol_total': 1.252279566576371e+22, 'H2_mol_atm': 1.679579696737052e+20, 'H2_mol_solid': 0.0, 'H2_mol_liquid': 0.0, 'H2_mol_total': 1.679579696737052e+20, 'CH4_mol_atm': 231363924225406.06, 'CH4_mol_solid': 0.0, 'CH4_mol_liquid': 28136436601611.617, 'CH4_mol_total': 259500360827017.7, 'CO_mol_atm': 6.2429717435845265e+22, 'CO_mol_solid': 0.0, 'CO_mol_liquid': 2.828618449918538e+22, 'CO_mol_total': 9.071590193503065e+22, 'N2_mol_atm': 4.4488500793923857e+21, 'N2_mol_solid': 0.0, 'N2_mol_liquid': 9.918502128691809e+20, 'N2_mol_total': 5.440700292261566e+21, 'S2_mol_atm': 2.6860327942104604e+16, 'S2_mol_solid': 0.0, 'S2_mol_liquid': 1.783329938406811e+23, 'S2_mol_total': 1.7833302070100906e+23, 'SO2_mol_atm': 5.985896291186619e+17, 'SO2_mol_solid': 0.0, 'SO2_mol_liquid': 0.0, 'SO2_mol_total': 5.985896291186619e+17, 'H2S_mol_atm': 5.7367162940299014e+17, 'H2S_mol_solid': 0.0, 'H2S_mol_liquid': 0.0, 'H2S_mol_total': 5.7367162940299014e+17, 'H/O_atm': 0.00043632921962552214, 'H/C_atm': 0.000625742381049505, 'H/N_atm': 0.00407175236116406, 'H/S_atm': 13.200108860855687, 'O/H_atm': 2291.8474285500433, 'O/C_atm': 1.4341060669430892, 'O/N_atm': 9.331835178626418, 'O/S_atm': 30252.63554933275, 'C/H_atm': 1598.1017592619894, 'C/O_atm': 0.697298493500958, 'C/N_at ...
# Partial pressures
#     H2O : 0.308 bar
#     CO2 : 18.830 bar
#     N2 : 16.458 bar
#     H2 : 0.621 bar
#     CO : 230.956 bar
#     CH4 : 0.000 bar
#     S2 : 0.000 bar
#     SO2 : 0.002 bar
#     H2S : 0.002 bar
# mubar = 0.02906625835051719
# ptot = 267.178 bar
#
# {'H2O': 1.4978517566893906e+18, 'CO2': 2.2388979380013908e+20, 'N2': 1.2456690439616143e+20, 'H2': 3.384114658232036e+17, 'CO': 1.7477698969270278e+21, 'CH4': 3709195998855.315, 'S2': 1720874174449337.8, 'SO2': 3.83298018746569e+16, 'H2S': 1.955228542466512e+16}
# 5.0604965139661555e+17 8.105661410487734e+20 1.2456690439616143e+20 1720874174449337.8

# %% [markdown]
# ### Check results

# %%
H_mol = H_kg / (1.0e-3)
H_oc  = H_mol / (7.69e22 * 2.0)

print("[H] atm = %.4f" % H_oc)
print("C/H atm = %.4f" % (C_kg/H_kg))
# Out:
# [H] atm = 0.0033
# C/H atm = 1601.7522

# %% [markdown]
# ### Parameter sweep demo

# %%
plt.close("all")

# parameters
x_arr = np.linspace(-6, 6, 60)
x_key = "fO2_shift_IW"

y_keys = [v+"_vmr" for v in solvevol_vols]
y_keys.extend([v+"_bar" for v in solvevol_vols])

# run model
y_out = {}
for y in y_keys:
    y_out[y] = []
for x in x_arr:
    OPTIONS = deepcopy(BACKUP_options)
    OPTIONS[x_key] = x
    solvevol_target = get_target_from_params(OPTIONS)
    p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)
    for y in y_keys:
        y_out[y].append(p_d[y])


# plot data
fig,ax = plt.subplots(1,1)

for y in y_keys:
    if "_vmr" in y:
        ax.plot(x_arr, y_out[y], label=y)
ax.set(xlabel=x_key, ylabel="VMR")
ax.legend()
ax.set_yscale("log")
plt.show()


# write to csv
M = []
header = x_key
M.append(x_arr)
for y in y_keys:
    M.append(y_out[y])
    header += " "+y
M = np.array(M).T
np.savetxt("nogit_solvevol.csv", M, fmt="%.4e", header=header, comments="")
