# %% [markdown]
# # Solve surface volatiles according to outgassing+chemistry

# %%
import sys
sys.path.append("..")
from calliope.surface_gases import *
from calliope.constants import R_earth, const_G, M_earth

from copy import deepcopy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Set up initial options dict

# %%
OPTIONS = {}

OPTIONS['Phi_global'] = 1.0
OPTIONS['T_magma'] = 2500.0

OPTIONS['radius'] = R_earth * 1.875
OPTIONS['mass']   = M_earth * 7.99
OPTIONS['gravity'] = const_G * OPTIONS['mass'] / (OPTIONS['radius']**2)
OPTIONS['hydrogen_earth_oceans'] = 8.0
OPTIONS['CH_ratio'] = 1.0
OPTIONS['fO2_shift_IW'] = 0.0
OPTIONS['nitrogen_ppmw'] = 4.0
OPTIONS['sulfur_ppmw'] = 300.0
OPTIONS['planet_coresize'] = 0.5

solvevol_vols = ['H2O', 'CO2', 'N2', 'H2', 'CO', 'CH4', 'S2', 'SO2']
for v in solvevol_vols:
    OPTIONS[v+"_included"] = 0
    OPTIONS[v+"_initial_bar"] = 0.0

OPTIONS["H2O_included"] = 1
OPTIONS["CO2_included"] = 1
OPTIONS["N2_included"]  = 1
OPTIONS["S2_included"]  = 1

OPTIONS["H2_included"]  = 1
OPTIONS["CO_included"]  = 1
OPTIONS["CH4_included"] = 1
OPTIONS["SO2_included"] = 1

# OPTIONS["H2O_initial_bar"] = 1.0
# OPTIONS["CO2_initial_bar"] = 0.0
# OPTIONS["N2_initial_bar"]  = 0.0

print("Gravity = %.3f m.s-2" % OPTIONS["gravity"])
# Out:
# Gravity = 22.569 m.s-2

# %% [markdown]
# ### Calculate total amount of each element in the system

# %%
OPTIONS["M_mantle"] = CalculateMantleMass(OPTIONS["radius"], OPTIONS["mass"], OPTIONS["planet_coresize"])
BACKUP_options = deepcopy(OPTIONS)

# %%
solvevol_target = get_target_from_params(OPTIONS)
# solvevol_target = get_target_from_pressures(OPTIONS)

print("Targets:")
print(solvevol_target)
# Out:
# Targets:
# {'H': 1.24e+21, 'C': 1.24e+21, 'N': 1.53050887657802e+20, 'S': 1.147881657433515e+22}

# %% [markdown]
# ### Solve for equilibrium atmospheric partial pressures, etc.

# %%
p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)

print(p_d)

p_bar = {}
for v in volatile_species:
    p_bar[v] = p_d[v+"_bar"]

mubar = 0.0
ptot = 0.0
print("Partial pressures")
for v in solvevol_vols:
    print("    %s : %.3f bar"%(v, p_bar[v]))
    ptot += p_bar[v]
    mubar += p_bar[v]*molar_mass[v]
mubar /= ptot

print("mubar =",mubar)
print("ptot = %.3f bar"%ptot)

m_d = {}
for v in solvevol_vols:
    m_d[v] = p_bar[v]*1.0e5 * 4 * 3.14 * (molar_mass[v]/mubar) * OPTIONS["radius"]**2.0 / OPTIONS["gravity"]

# print(solvevol_atmosphere_mass(p_bar, OPTIONS))

print(" ")
print(m_d)

H_kg = (2*m_d["H2O"]/molar_mass["H2O"] + 2*m_d["H2"]/molar_mass["H2"] + 4*m_d["CH4"]/molar_mass["CH4"]) *molar_mass['H']
C_kg = (m_d["CO2"]/molar_mass["CO2"] + m_d["CO"]/molar_mass["CO"] + m_d["CH4"]/molar_mass["CH4"]) * molar_mass['C']
N_kg = m_d["N2"]
S_kg = m_d["S2"]

print(H_kg, C_kg, N_kg, S_kg)
# Out:
# {'M_atm': np.float64(2.096612941461928e+21), 'P_surf': np.float64(266.8501535794383), 'H2O_bar': np.float64(0.3051955948716073), 'H2O_kg_atm': np.float64(1.4862048183131968e+18), 'H2O_kg_liquid': np.float64(1.1076340010140471e+22), 'H2O_kg_solid': 0.0, 'H2O_kg_total': np.float64(1.1077826214958784e+22), 'CO2_bar': np.float64(18.801396521466792), 'CO2_kg_atm': np.float64(2.236664604454997e+20), 'CO2_kg_liquid': np.float64(3.279967127744856e+20), 'CO2_kg_solid': 0.0, 'CO2_kg_total': np.float64(5.5166317321998526e+20), 'H2_bar': np.float64(0.6162129729178871), 'H2_kg_atm': np.float64(3.357800588961577e+17), 'H2_kg_liquid': 0.0, 'H2_kg_solid': 0.0, 'H2_kg_total': np.float64(3.357800588961577e+17), 'CH4_bar': np.float64(8.405554978557533e-07), 'CH4_kg_atm': np.float64(3644434462280.5327), 'CH4_kg_liquid': np.float64(445053082736.94196), 'CH4_kg_solid': 0.0, 'CH4_kg_total': np.float64(4089487545017.4746), 'CO_bar': np.float64(230.610101576547), 'CO_kg_atm': np.float64(1.746026470808342e+21), 'CO_kg_liquid': np.float64(7.945854845207128e+20), 'CO_kg_solid': 0.0, 'CO_kg_total': np.float64(2.540611955329055e+21), 'N2_bar': np.float64(16.51493224214309), 'N2_kg_atm': np.float64(1.2505795083980453e+20), 'N2_kg_liquid': np.float64(2.79929368179972e+19), 'N2_kg_solid': 0.0, 'N2_kg_total': np.float64(1.530508876578017e+20), 'S2_bar': np.float64(9.936902735189433e-05), 'S2_kg_atm': np.float64(1721743515720785.2), 'S2_kg_liquid': np.float64(1.147879652248249e+22), 'S2_kg_solid': 0.0, 'S2_kg_total': np.float64(1.1478798244226005e+22), 'SO2_bar': np.float64(0.0022144619091064746), 'SO2_kg_atm': np.float64(3.83491031219629e+16), 'SO2_kg_liquid': 0.0, 'SO2_kg_solid': 0.0, 'SO2_kg_total': np.float64(3.83491031219629e+16), 'H2O_vmr': np.float64(0.0011436965307226401), 'CO2_vmr': np.float64(0.07045675735715785), 'H2_vmr': np.float64(0.0023092097368212585), 'CH4_vmr': np.float64(3.1499157357821393e-09), 'CO_vmr': np.float64(0.8641932503437625), 'N2_vmr': np.float64(0.061888411981845755), 'S2_vmr': np.float64(3.7237762848921603e-07), 'SO2_vmr': np.float64(8.29852214586511e-06), 'H_kg_atm': np.float64(5.021147208514642e+17), 'H_kg_liquid': np.float64(1.2394978852650984e+21), 'H_kg_solid': 0.0, 'H_kg_total': np.float64(1.2399999999859499e+21), 'C_kg_atm': np.float64(8.09757589383233e+20), 'C_kg_liquid': np.float64(4.302424106167676e+20), 'C_kg_solid': 0.0, 'C_kg_total': np.float64(1.2400000000000005e+21), 'N_kg_atm': np.float64(1.2505795083980453e+20), 'N_kg_liquid': np.float64(2.79929368179972e+19), 'N_kg_solid': 0.0, 'N_kg_total': np.float64(1.530508876578017e+20), 'S_kg_atm': np.float64(2.0051853782534864e+16), 'S_kg_liquid': np.float64(1.147879652248249e+22), 'S_kg_solid': 0.0, 'S_kg_total': np.float64(1.1478816574336271e+22), 'O_kg_atm': np.float64(1.161269283988441e+21), 'O_kg_liquid': np.float64(1.0529002306737959e+22), 'O_kg_solid': 0.0, 'O_kg_total': np.float64(1.16902715907264e+22), 'atm_kg_per_mol': np.float64(0.02906641148268742), 'H2O_mol_atm': np.float64(8.249690364586045e+19), 'H2O_mol_solid': 0.0, 'H2O_mol_liquid': np.float64(6.148303001752107e+23), 'H2O_mol_total': np.float64(6.149127970788566e+23), 'CO2_mol_atm': np.float64(5.082173607032485e+21), 'CO2_mol_solid': 0.0, 'CO2_mol_liquid': np.float64(7.452776931935596e+21), 'CO2_mol_total': np.float64(1.2534950538968081e+22), 'H2_mol_atm': np.float64(1.6656748362807198e+20), 'H2_mol_solid': 0.0, 'H2_mol_liquid': 0.0, 'H2_mol_total': np.float64(1.6656748362807198e+20), 'CH4_mol_atm': np.float64(227209131064871.12), 'CH4_mol_solid': 0.0, 'CH4_mol_liquid': np.float64(27746451542203.367), 'CH4_mol_total': np.float64(254955582607074.5), 'CO_mol_atm': np.float64(6.233582544835208e+22), 'CO_mol_solid': 0.0, 'CO_mol_liquid': np.float64(2.836792161801902e+22), 'CO_mol_total': np.float64(9.07037470663711e+22), 'N2_mol_atm': np.float64(4.464123325473139e+21), 'N2_mol_solid': 0.0, 'N2_mol_liquid': np.float64(9.9924811944018e+20), 'N2_mol_total': np.float64(5.463371444913319e+21), 'S2_mol_atm': np.flo ...
# Partial pressures
#     H2O : 0.305 bar
#     CO2 : 18.801 bar
#     N2 : 16.515 bar
#     H2 : 0.616 bar
#     CO : 230.610 bar
#     CH4 : 0.000 bar
#     S2 : 0.000 bar
#     SO2 : 0.002 bar
# mubar = 0.029066411482687425
# ptot = 266.850 bar
#
# {'H2O': np.float64(1.485451380754989e+18), 'CO2': np.float64(2.235530718265593e+20), 'N2': np.float64(1.2499455220460013e+20), 'H2': np.float64(3.3560983383393734e+17), 'CO': np.float64(1.7451413156099992e+21), 'CH4': np.float64(3642586901454.141), 'S2': np.float64(1720870670864974.8), 'SO2': np.float64(3.832966188865531e+16)}
# 5.0186017175799014e+17 8.093470794902712e+20 1.2499455220460013e+20 1720870670864974.8
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:305: RuntimeWarning: invalid value encountered in scalar power
#   p_d['SO2']  = (gamma*pin['S2']*p_d['O2']**2)**0.5
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:249: RuntimeWarning: invalid value encountered in log10
#   ppmw = 10 ** (-0.738 + 0.876 * np.log10(p) - 5.44e-5 * p_total)
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:117: RuntimeWarning: invalid value encountered in scalar power
#   return const*p**exponent

# %% [markdown]
# ### Check results

# %%
H_mol = H_kg / (1.0e-3)
H_oc  = H_mol / (7.69e22 * 2.0)

print("[H] atm = %.4f" % H_oc)
print("C/H atm = %.4f" % (C_kg/H_kg))
# Out:
# [H] atm = 0.0033
# C/H atm = 1612.6944

# %% [markdown]
# ### Parameter sweep demo

# %%
plt.close("all")

# parameters
x_arr = np.linspace(-6, 6, 60)
x_key = "fO2_shift_IW"
y_keys = [v+"_vmr" for v in solvevol_vols]
y_keys.extend([v+"_bar" for v in solvevol_vols])

# run model
y_out = {}
for y in y_keys:
    y_out[y] = []
for x in x_arr:
    OPTIONS = deepcopy(BACKUP_options)
    OPTIONS[x_key] = x
    solvevol_target = get_target_from_params(OPTIONS)
    p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)
    for y in y_keys:
        y_out[y].append(p_d[y])


# plot data
fig,ax = plt.subplots(1,1)

for y in y_keys:
    if "_vmr" in y:
        ax.plot(x_arr, y_out[y], label=y)
ax.set(xlabel=x_key, ylabel="Volume mixing ratio")
ax.legend()
ax.set_yscale("log")

plt.show()


# write to csv
M = []
header = x_key
M.append(x_arr)
for y in y_keys:
    M.append(y_out[y])
    header += " "+y
M = np.array(M).T
np.savetxt("nogit_solvevol.csv", M, fmt="%.4e", header=header, comments="")
# Out:
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:222: RuntimeWarning: invalid value encountered in scalar power
#   ppmw  = pb_N2**0.5 * np.exp(5908.0 * pb_tot**0.5/temp - 1.6*fO2_shift)
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:222: RuntimeWarning: overflow encountered in exp
#   ppmw  = pb_N2**0.5 * np.exp(5908.0 * pb_tot**0.5/temp - 1.6*fO2_shift)
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:237: RuntimeWarning: overflow encountered in exp
#   ppmw = p*np.exp(4.93 - (0.000193 * p_total))
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:419: RuntimeWarning: overflow encountered in scalar multiply
#   mass_int_d['N2'] = prefactor*ppmw_N2
