# %% [markdown]
# # Solve surface volatiles according to outgassing+chemistry

# %%
import sys
sys.path.append("..") 
from calliope.surface_gases import *

from copy import deepcopy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Set up initial options dict

# %%
OPTIONS = {}

OPTIONS['Phi_global'] = 1.0
OPTIONS['T_magma'] = 2500.0

OPTIONS['radius'] = 6.371e6 * 1.875
OPTIONS['mass']   = 5.972e24 * 7.99
OPTIONS['gravity'] = 6.67e-11 * OPTIONS['mass'] / (OPTIONS['radius']**2)
OPTIONS['hydrogen_earth_oceans'] = 8.0
OPTIONS['CH_ratio'] = 1.0
OPTIONS['fO2_shift_IW'] = 0.0
OPTIONS['nitrogen_ppmw'] = 4.0
OPTIONS['sulfur_ppmw'] = 300.0
OPTIONS['planet_coresize'] = 0.5

solvevol_vols = ['H2O', 'CO2', 'N2', 'H2', 'CO', 'CH4', 'S2', 'SO2']
for v in solvevol_vols:
    OPTIONS[v+"_included"] = 0
    OPTIONS[v+"_initial_bar"] = 0.0

OPTIONS["H2O_included"] = 1
OPTIONS["CO2_included"] = 1
OPTIONS["N2_included"]  = 1
OPTIONS["S2_included"]  = 1

OPTIONS["H2_included"]  = 1
OPTIONS["CO_included"]  = 1
OPTIONS["CH4_included"] = 1
OPTIONS["SO2_included"] = 1

# OPTIONS["H2O_initial_bar"] = 1.0
# OPTIONS["CO2_initial_bar"] = 0.0
# OPTIONS["N2_initial_bar"]  = 0.0

print("Gravity = %.3f m.s-2" % OPTIONS["gravity"])
# Out:
# Gravity = 22.304 m.s-2

# %% [markdown]
# ### Calculate total amount of each element in the system

# %%
OPTIONS["M_mantle"] = CalculateMantleMass(OPTIONS["radius"], OPTIONS["mass"], OPTIONS["planet_coresize"])
BACKUP_options = deepcopy(OPTIONS)

# %%
solvevol_target = get_target_from_params(OPTIONS)
# solvevol_target = get_target_from_pressures(OPTIONS)

print("Targets:")
print(solvevol_target)
# Out:
# Targets:
# {'H': 1.24e+21, 'C': 1.24e+21, 'N': 1.5241054973730108e+20, 'S': 1.143079123029758e+22}

# %% [markdown]
# ### Solve for equilibrium atmospheric partial pressures, etc.

# %%
p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)

print(p_d)

p_bar = {}
for v in volatile_species:
    p_bar[v] = p_d[v+"_bar"]

mubar = 0.0
ptot = 0.0
print("Partial pressures")
for v in solvevol_vols:
    print("    %s : %.3f bar"%(v, p_bar[v]))
    ptot += p_bar[v]
    mubar += p_bar[v]*molar_mass[v]
mubar /= ptot

print("mubar =",mubar)
print("ptot = %.3f bar"%ptot)

m_d = {}
for v in solvevol_vols:
    m_d[v] = p_bar[v]*1.0e5 * 4 * 3.14 * (molar_mass[v]/mubar) * OPTIONS["radius"]**2.0 / OPTIONS["gravity"]

# print(solvevol_atmosphere_mass(p_bar, OPTIONS))

print(" ")
print(m_d)

H_kg = (2*m_d["H2O"]/molar_mass["H2O"] + 2*m_d["H2"]/molar_mass["H2"] + 4*m_d["CH4"]/molar_mass["CH4"]) *molar_mass['H']
C_kg = (m_d["CO2"]/molar_mass["CO2"] + m_d["CO"]/molar_mass["CO"] + m_d["CH4"]/molar_mass["CH4"]) * molar_mass['C']
N_kg = m_d["N2"]
S_kg = m_d["S2"]

print(H_kg, C_kg, N_kg, S_kg)
# Out:
# {'M_atm': np.float64(2.114084298082597e+21), 'P_surf': np.float64(262.94767901868516), 'H2O_bar': np.float64(0.3077575189059737), 'H2O_kg_atm': np.float64(1.5336596973296049e+18), 'H2O_kg_liquid': np.float64(1.107619674017996e+22), 'H2O_kg_solid': 0.0, 'H2O_kg_total': np.float64(1.107773039987729e+22), 'CO2_bar': np.float64(18.534278184620327), 'CO2_kg_atm': np.float64(2.256349453500219e+20), 'CO2_kg_liquid': np.float64(3.2199343646294835e+20), 'CO2_kg_solid': 0.0, 'CO2_kg_total': np.float64(5.476283818129702e+20), 'H2_bar': np.float64(0.6213856911750784), 'H2_kg_atm': np.float64(3.4650159732389926e+17), 'H2_kg_liquid': 0.0, 'H2_kg_solid': 0.0, 'H2_kg_total': np.float64(3.4650159732389926e+17), 'CH4_bar': np.float64(8.425831775253995e-07), 'CH4_kg_atm': np.float64(3738492075576.184), 'CH4_kg_liquid': np.float64(444260206414.45154), 'CH4_kg_solid': 0.0, 'CH4_kg_total': np.float64(4182752281990.6357), 'CO_bar': np.float64(227.33373927426862), 'CO_kg_atm': np.float64(1.761393221566755e+21), 'CO_kg_liquid': np.float64(7.817866615092478e+20), 'CO_kg_solid': 0.0, 'CO_kg_total': np.float64(2.543179883076003e+21), 'N2_bar': np.float64(16.14820367631334), 'N2_kg_atm': np.float64(1.2513496003657279e+20), 'N2_kg_liquid': np.float64(2.7275589700731507e+19), 'N2_kg_solid': 0.0, 'N2_kg_total': np.float64(1.524105497373043e+20), 'S2_bar': np.float64(9.936901764908393e-05), 'S2_kg_atm': np.float64(1761928751038047.8), 'S2_kg_liquid': np.float64(1.1430770704263986e+22), 'S2_kg_solid': 0.0, 'S2_kg_total': np.float64(1.1430772466192738e+22), 'SO2_bar': np.float64(0.0022144618009917777), 'SO2_kg_atm': np.float64(3.924416735070671e+16), 'SO2_kg_liquid': 0.0, 'SO2_kg_solid': 0.0, 'SO2_kg_total': np.float64(3.924416735070671e+16), 'H2O_vmr': np.float64(0.0011704135212545622), 'CO2_vmr': np.float64(0.07048656315883767), 'H2_vmr': np.float64(0.0023631533599919033), 'CH4_vmr': np.float64(3.204375793199244e-09), 'CO_vmr': np.float64(0.8645588358972136), 'N2_vmr': np.float64(0.0614122312719324), 'S2_vmr': np.float64(3.7790414435269733e-07), 'SO2_vmr': np.float64(8.421682249701156e-06), 'H_kg_atm': np.float64(5.1814735962503546e+17), 'H_kg_liquid': np.float64(1.2394818526392397e+21), 'H_kg_solid': 0.0, 'H_kg_total': np.float64(1.2399999999988647e+21), 'C_kg_atm': np.float64(8.16884252890267e+20), 'C_kg_liquid': np.float64(4.23115747109737e+20), 'C_kg_solid': 0.0, 'C_kg_total': np.float64(1.240000000000004e+21), 'N_kg_atm': np.float64(1.2513496003657279e+20), 'N_kg_liquid': np.float64(2.7275589700731507e+19), 'N_kg_solid': 0.0, 'N_kg_total': np.float64(1.524105497373043e+20), 'S_kg_atm': np.float64(2.0519861999930156e+16), 'S_kg_liquid': np.float64(1.1430770704263986e+22), 'S_kg_solid': 0.0, 'S_kg_total': np.float64(1.1430791224125987e+22), 'O_kg_atm': np.float64(1.1715204022327544e+21), 'O_kg_liquid': np.float64(1.051719977222039e+22), 'O_kg_solid': 0.0, 'O_kg_total': np.float64(1.1688720174453145e+22), 'atm_kg_per_mol': np.float64(0.029065221864398694), 'H2O_mol_atm': np.float64(8.513104971610792e+19), 'H2O_mol_solid': 0.0, 'H2O_mol_liquid': np.float64(6.148223474839114e+23), 'H2O_mol_total': np.float64(6.149074785336276e+23), 'CO2_mol_atm': np.float64(5.12690173483349e+21), 'CO2_mol_solid': 0.0, 'CO2_mol_liquid': np.float64(7.316369835558927e+21), 'CO2_mol_total': np.float64(1.2443271570392416e+22), 'H2_mol_atm': np.float64(1.7188602363429336e+20), 'H2_mol_solid': 0.0, 'H2_mol_liquid': 0.0, 'H2_mol_total': np.float64(1.7188602363429336e+20), 'CH4_mol_atm': np.float64(233073072043403.03), 'CH4_mol_solid': 0.0, 'CH4_mol_liquid': np.float64(27697020350028.152), 'CH4_mol_total': np.float64(260770092393431.2), 'CO_mol_atm': np.float64(6.2884442040940915e+22), 'CO_mol_solid': 0.0, 'CO_mol_liquid': np.float64(2.791098398819164e+22), 'CO_mol_total': np.float64(9.079542602913256e+22), 'N2_mol_atm': np.float64(4.466872279452159e+21), 'N2_mol_solid': 0.0, 'N2_mol_liquid': np.float64(9.736413829061007e+20), 'N2_mol_total': np.float64(5.44051366235826e+21), 'S2_mol_ ...
# Partial pressures
#     H2O : 0.308 bar
#     CO2 : 18.534 bar
#     N2 : 16.148 bar
#     H2 : 0.621 bar
#     CO : 227.334 bar
#     CH4 : 0.000 bar
#     S2 : 0.000 bar
#     SO2 : 0.002 bar
# mubar = 0.02906522186439869
# ptot = 262.948 bar
#
# {'H2O': np.float64(1.5328822024061588e+18), 'CO2': np.float64(2.2552055881116516e+20), 'N2': np.float64(1.2507152236761439e+20), 'H2': np.float64(3.463259369519443e+17), 'CO': np.float64(1.760500276221484e+21), 'CH4': np.float64(3736596832051.714), 'S2': np.float64(1761035534203967.0), 'SO2': np.float64(3.922427236295735e+16)}
# 5.178846827467118e+17 8.164701301479332e+20 1.2507152236761439e+20 1761035534203967.0
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:305: RuntimeWarning: invalid value encountered in scalar power
#   p_d['SO2']  = (gamma*pin['S2']*p_d['O2']**2)**0.5
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:117: RuntimeWarning: invalid value encountered in scalar power
#   return const*p**exponent

# %% [markdown]
# ### Check results

# %%
H_mol = H_kg / (1.0e-3)
H_oc  = H_mol / (7.69e22 * 2.0)


print("[H] atm = %.4f" % H_oc)
print("C/H atm = %.4f" % (C_kg/H_kg))
# Out:
# [H] atm = 0.0034
# C/H atm = 1576.5481

# %% [markdown]
# ### Parameter sweep demo

# %%
plt.close("all")

# parameters
x_arr = np.linspace(-6, 6, 60)
x_key = "fO2_shift_IW"
y_keys = [v+"_vmr" for v in solvevol_vols]
y_keys.extend([v+"_bar" for v in solvevol_vols])

# run model
y_out = {}
for y in y_keys:
    y_out[y] = []
for x in x_arr:
    OPTIONS = deepcopy(BACKUP_options)
    OPTIONS[x_key] = x
    solvevol_target = get_target_from_params(OPTIONS)
    p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)
    for y in y_keys:
        y_out[y].append(p_d[y])


# plot data
fig,ax = plt.subplots(1,1)

for y in y_keys:
    if "_vmr" in y:
        ax.plot(x_arr, y_out[y], label=y)
ax.set(xlabel=x_key, ylabel="Volume mixing ratio")
ax.legend()
ax.set_yscale("log")

plt.show()


# write to csv
M = []
header = x_key
M.append(x_arr)
for y in y_keys:
    M.append(y_out[y])
    header += " "+y
M = np.array(M).T
np.savetxt("nogit_solvevol.csv", M, fmt="%.4e", header=header, comments="")
# Out:
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:222: RuntimeWarning: invalid value encountered in scalar power
#   ppmw  = pb_N2**0.5 * np.exp(5908.0 * pb_tot**0.5/temp - 1.6*fO2_shift)
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:222: RuntimeWarning: overflow encountered in exp
#   ppmw  = pb_N2**0.5 * np.exp(5908.0 * pb_tot**0.5/temp - 1.6*fO2_shift)
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:249: RuntimeWarning: invalid value encountered in log10
#   ppmw = 10 ** (-0.738 + 0.876 * np.log10(p) - 5.44e-5 * p_total)
# /dataserver/users/formingworlds/nicholls/CALLIOPE/src/calliope/surface_gases.py:237: RuntimeWarning: overflow encountered in exp
#   ppmw = p*np.exp(4.93 - (0.000193 * p_total))
