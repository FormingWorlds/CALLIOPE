# %% [markdown]
# # Solve surface volatiles according to outgassing+chemistry

# %%
import sys
sys.path.append("..")
from calliope.solve import *
from calliope.structure import calculate_mantle_mass
from calliope.constants import R_earth, const_G, M_earth

from copy import deepcopy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Set up initial options dict

# %%
OPTIONS = {}

OPTIONS['Phi_global'] = 1.0
OPTIONS['T_magma'] = 2500.0

OPTIONS['radius'] = R_earth * 1.875
OPTIONS['mass']   = M_earth * 7.99
OPTIONS['gravity'] = const_G * OPTIONS['mass'] / (OPTIONS['radius']**2)
OPTIONS['hydrogen_earth_oceans'] = 8.0
OPTIONS['CH_ratio'] = 1.0
OPTIONS['fO2_shift_IW'] = 0.0
OPTIONS['nitrogen_ppmw'] = 4.0
OPTIONS['sulfur_ppmw'] = 300.0
OPTIONS['planet_coresize'] = 0.5

solvevol_vols = ['H2O', 'CO2', 'N2', 'H2', 'CO', 'CH4', 'S2', 'SO2', 'H2S', 'NH3']
for v in solvevol_vols:
    OPTIONS[v+"_included"] = 0
    OPTIONS[v+"_initial_bar"] = 0.0

OPTIONS["H2O_included"] = 1
OPTIONS["CO2_included"] = 1
OPTIONS["N2_included"]  = 1
OPTIONS["S2_included"]  = 1

OPTIONS["H2_included"]  = 1
OPTIONS["CO_included"]  = 1
OPTIONS["CH4_included"] = 1
OPTIONS["SO2_included"] = 1
OPTIONS["H2S_included"] = 1
OPTIONS["NH3_included"] = 1

# OPTIONS["H2O_initial_bar"] = 1.0
# OPTIONS["CO2_initial_bar"] = 0.0
# OPTIONS["N2_initial_bar"]  = 0.0

print("Gravity = %.3f m.s-2" % OPTIONS["gravity"])
# Out:
# Gravity = 22.569 m.s-2

# %% [markdown]
# ### Calculate total amount of each element in the system

# %%
OPTIONS["M_mantle"] = calculate_mantle_mass(OPTIONS["radius"], OPTIONS["mass"], OPTIONS["planet_coresize"])
BACKUP_options = deepcopy(OPTIONS)

# %%
solvevol_target = get_target_from_params(OPTIONS)
# solvevol_target = get_target_from_pressures(OPTIONS)

print("Targets:")
print(solvevol_target)
# Out:
# Targets:
# {'H': 1.24e+21, 'C': 1.24e+21, 'N': 1.5241577798741547e+20, 'S': 1.1431183349056161e+22}

# %% [markdown]
# ### Solve for equilibrium atmospheric partial pressures, etc.

# %%
p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)

print(p_d)

p_bar = {}
for v in volatile_species:
    p_bar[v] = p_d[v+"_bar"]

mubar = 0.0
ptot = 0.0
print("Partial pressures")
for v in solvevol_vols:
    print("    %s : %.3f bar"%(v, p_bar[v]))
    ptot += p_bar[v]
    mubar += p_bar[v]*molar_mass[v]
mubar /= ptot

print("mubar =",mubar)
print("ptot = %.3f bar"%ptot)

m_d = {}
for v in solvevol_vols:
    m_d[v] = p_bar[v]*1.0e5 * 4 * 3.14 * (molar_mass[v]/mubar) * OPTIONS["radius"]**2.0 / OPTIONS["gravity"]

# print(solvevol_atmosphere_mass(p_bar, OPTIONS))

print(" ")
print(m_d)

H_kg = (2*m_d["H2O"]/molar_mass["H2O"] + 2*m_d["H2"]/molar_mass["H2"] + 4*m_d["CH4"]/molar_mass["CH4"]) *molar_mass['H']
C_kg = (m_d["CO2"]/molar_mass["CO2"] + m_d["CO"]/molar_mass["CO"] + m_d["CH4"]/molar_mass["CH4"]) * molar_mass['C']
N_kg = m_d["N2"]
S_kg = m_d["S2"]

print(H_kg, C_kg, N_kg, S_kg)
# Out:
# {'M_atm': 2.0991601523118986e+21, 'P_surf': 267.17435438498876, 'H2O_bar': 0.30773893685569637, 'H2O_kg_atm': 1.498612118447389e+18, 'H2O_kg_liquid': 1.107624229440258e+22, 'H2O_kg_solid': 0.0, 'H2O_kg_total': 1.1077740906521026e+22, 'CO2_bar': 18.829493924961128, 'CO2_kg_atm': 2.2400400897854184e+20, 'CO2_kg_liquid': 3.2712275869527225e+20, 'CO2_kg_solid': 0.0, 'CO2_kg_total': 5.511267676738141e+20, 'H2_bar': 0.6213481726111255, 'H2_kg_atm': 3.385832552782887e+17, 'H2_kg_liquid': 0.0, 'H2_kg_solid': 0.0, 'H2_kg_total': 3.385832552782887e+17, 'CH4_bar': 8.559005562974194e-07, 'CH4_kg_atm': 3711021301233.259, 'CH4_kg_liquid': 451297368226.46564, 'CH4_kg_solid': 0.0, 'CH4_kg_total': 4162318669459.7246, 'CO_bar': 230.95473262916417, 'CO_kg_atm': 1.7486615045666447e+21, 'CO_kg_liquid': 7.922918439400605e+20, 'CO_kg_solid': 0.0, 'CO_kg_total': 2.540953348506705e+21, 'N2_bar': 16.449769461915267, 'N2_kg_atm': 1.2456634302057828e+20, 'N2_kg_liquid': 2.7771805340065882e+19, 'N2_kg_solid': 0.0, 'N2_kg_total': 1.5233814836064417e+20, 'S2_bar': 9.936870614487729e-05, 'S2_kg_atm': 1721763271070936.2, 'S2_kg_liquid': 1.1431144904972673e+22, 'S2_kg_solid': 0.0, 'S2_kg_total': 1.1431146626735944e+22, 'SO2_bar': 0.002214458330017004, 'SO2_kg_atm': 3.8349605122971304e+16, 'SO2_kg_liquid': 0.0, 'SO2_kg_solid': 0.0, 'SO2_kg_total': 3.8349605122971304e+16, 'H2S_bar': 0.002122256057835018, 'H2S_kg_atm': 1.9562210845856452e+16, 'H2S_kg_liquid': 0.0, 'H2S_kg_solid': 0.0, 'H2S_kg_total': 1.9562210845856452e+16, 'NH3_bar': 0.006834320486872214, 'NH3_kg_atm': 3.14630821471789e+16, 'NH3_kg_liquid': 0.0, 'NH3_kg_solid': 0.0, 'NH3_kg_total': 3.14630821471789e+16, 'H2O_vmr': 0.0011518281294777848, 'CO2_vmr': 0.07047642715673412, 'H2_vmr': 0.002325628049299166, 'CH4_vmr': 3.203528116565024e-09, 'CO_vmr': 0.8644345119156407, 'N2_vmr': 0.06156941784244656, 'S2_vmr': 3.719245672872124e-07, 'SO2_vmr': 8.28843896755917e-06, 'H2S_vmr': 7.94333746111321e-06, 'NH3_vmr': 2.5580001877815715e-05, 'H_kg_atm': 5.13049602181049e+17, 'H_kg_liquid': 1.2394869503865224e+21, 'H_kg_solid': 0.0, 'H_kg_total': 1.2399999999887034e+21, 'C_kg_atm': 8.109796434010893e+20, 'C_kg_liquid': 4.2902035659888624e+20, 'C_kg_solid': 0.0, 'C_kg_total': 1.2399999999999756e+21, 'N_kg_atm': 1.2464397264742969e+20, 'N_kg_liquid': 2.7771805340065882e+19, 'N_kg_solid': 0.0, 'N_kg_total': 1.5241577798749556e+20, 'S_kg_atm': 3.8444035101698536e+16, 'S_kg_liquid': 1.1431144904972673e+22, 'S_kg_solid': 0.0, 'S_kg_total': 1.1431183349007776e+22, 'O_kg_atm': 1.1630308235610136e+21, 'O_kg_liquid': 1.0526970006619713e+22, 'O_kg_solid': 0.0, 'O_kg_total': 1.1690000830180727e+22, 'atm_kg_per_mol': 0.029065984022399353, 'H2O_mol_atm': 8.318561345965141e+19, 'H2O_mol_solid': 0.0, 'H2O_mol_liquid': 6.148248761275194e+23, 'H2O_mol_total': 6.149080617409791e+23, 'CO2_mol_atm': 5.089843421461982e+21, 'CO2_mol_solid': 0.0, 'CO2_mol_liquid': 7.43291885242609e+21, 'CO2_mol_total': 1.2522762273888072e+22, 'H2_mol_atm': 1.6795804079523024e+20, 'H2_mol_solid': 0.0, 'H2_mol_liquid': 0.0, 'H2_mol_total': 1.6795804079523024e+20, 'CH4_mol_atm': 231360430251450.06, 'CH4_mol_solid': 0.0, 'CH4_mol_liquid': 28135746148782.15, 'CH4_mol_total': 259496176400232.22, 'CO_mol_atm': 6.242990019873776e+22, 'CO_mol_solid': 0.0, 'CO_mol_liquid': 2.8286035128170672e+22, 'CO_mol_total': 9.071593532690844e+22, 'N2_mol_atm': 4.4465746776818115e+21, 'N2_mol_solid': 0.0, 'N2_mol_liquid': 9.913545134599087e+20, 'N2_mol_total': 5.43792919114172e+21, 'S2_mol_atm': 2.6860581451964684e+16, 'S2_mol_solid': 0.0, 'S2_mol_liquid': 1.7833299383732718e+23, 'S2_mol_total': 1.7833302069790863e+23, 'SO2_mol_atm': 5.98595278665303e+17, 'SO2_mol_solid': 0.0, 'SO2_mol_liquid': 0.0, 'SO2_mol_total': 5.98595278665303e+17, 'H2S_mol_atm': 5.736718723125059e+17, 'H2S_mol_solid': 0.0, 'H2S_mol_liquid': 0.0, 'H2S_mol_total': 5.736718723125059e+17, 'NH3_mol_atm': 1.8474007484691973e+18, 'NH3_mol_solid': 0.0, 'NH3_mol_liquid': 0.0, 'NH3_mol_total': 1.8474007484691973e ...
# Partial pressures
#     H2O : 0.308 bar
#     CO2 : 18.829 bar
#     N2 : 16.450 bar
#     H2 : 0.621 bar
#     CO : 230.955 bar
#     CH4 : 0.000 bar
#     S2 : 0.000 bar
#     SO2 : 0.002 bar
#     H2S : 0.002 bar
#     NH3 : 0.007 bar
# mubar = 0.02906598402239935
# ptot = 267.174 bar
#
# {'H2O': 1.4978523909528215e+18, 'CO2': 2.238904492372189e+20, 'N2': 1.2450319360751432e+20, 'H2': 3.3841160912311046e+17, 'CO': 1.747775013521125e+21, 'CH4': 3709139983925.886, 'S2': 1720890416194036.2, 'SO2': 3.833016363503785e+16, 'H2S': 1.955229370368792e+16, 'NH3': 3.1447131810012396e+16}
# 5.060498656682245e+17 8.105685139800456e+20 1.2450319360751432e+20 1720890416194036.2

# %% [markdown]
# ### Check results

# %%
H_mol = H_kg / (1.0e-3)
H_oc  = H_mol / (7.69e22 * 2.0)

print("[H] atm = %.4f" % H_oc)
print("C/H atm = %.4f" % (C_kg/H_kg))
# Out:
# [H] atm = 0.0033
# C/H atm = 1601.7562

# %% [markdown]
# ### Parameter sweep demo

# %%
plt.close("all")

# parameters
x_arr = np.linspace(-6, 6, 60)
x_key = "fO2_shift_IW"

y_keys = [v+"_vmr" for v in solvevol_vols]
y_keys.extend([v+"_bar" for v in solvevol_vols])

# run model
y_out = {}
for y in y_keys:
    y_out[y] = []
for x in x_arr:
    OPTIONS = deepcopy(BACKUP_options)
    OPTIONS[x_key] = x
    solvevol_target = get_target_from_params(OPTIONS)
    p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)
    for y in y_keys:
        y_out[y].append(p_d[y])


# plot data
fig,ax = plt.subplots(1,1)

for y in y_keys:
    if "_vmr" in y:
        ax.plot(x_arr, y_out[y], label=y)
ax.set(xlabel=x_key, ylabel="VMR")
ax.legend()
ax.set_yscale("log")
plt.show()


# write to csv
M = []
header = x_key
M.append(x_arr)
for y in y_keys:
    M.append(y_out[y])
    header += " "+y
M = np.array(M).T
np.savetxt("nogit_solvevol.csv", M, fmt="%.4e", header=header, comments="")
