# %% [markdown]
# # Solve surface volatiles according to outgassing+chemistry

# %%
import sys
sys.path.append("..")
from calliope.solve import *
from calliope.structure import calculate_mantle_mass
from calliope.constants import R_earth, const_G, M_earth

from copy import deepcopy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Set up initial options dict

# %%
OPTIONS = {}

OPTIONS['Phi_global'] = 0.1
OPTIONS['T_magma'] = 2000.0

OPTIONS['radius'] = R_earth * 1.875
OPTIONS['mass']   = M_earth * 7.99
OPTIONS['gravity'] = const_G * OPTIONS['mass'] / (OPTIONS['radius']**2)
OPTIONS['hydrogen_earth_oceans'] = 8.0
OPTIONS['CH_ratio'] = 0.1
OPTIONS['fO2_shift_IW'] = -5
OPTIONS['nitrogen_ppmw'] = 4.0
OPTIONS['sulfur_ppmw'] = 500.0
OPTIONS['planet_coresize'] = 0.5

solvevol_vols = ['H2O', 'CO2', 'N2', 'H2', 'CO', 'CH4', 'S2', 'SO2', 'H2S']
for v in solvevol_vols:
    OPTIONS[v+"_included"] = 0
    OPTIONS[v+"_initial_bar"] = 0.0

OPTIONS["H2O_included"] = 1
OPTIONS["CO2_included"] = 1
OPTIONS["N2_included"]  = 1
OPTIONS["S2_included"]  = 1

OPTIONS["H2_included"]  = 1
OPTIONS["CO_included"]  = 1
OPTIONS["CH4_included"] = 1
OPTIONS["SO2_included"] = 1
OPTIONS["H2S_included"] = 1

# OPTIONS["H2O_initial_bar"] = 1.0
# OPTIONS["CO2_initial_bar"] = 0.0
# OPTIONS["N2_initial_bar"]  = 0.0

print("Gravity = %.3f m.s-2" % OPTIONS["gravity"])
# Out:
# Gravity = 22.569 m.s-2

# %% [markdown]
# ### Calculate total amount of each element in the system

# %%
OPTIONS["M_mantle"] = calculate_mantle_mass(OPTIONS["radius"], OPTIONS["mass"], OPTIONS["planet_coresize"])
BACKUP_options = deepcopy(OPTIONS)

# %%
solvevol_target = get_target_from_params(OPTIONS)
# solvevol_target = get_target_from_pressures(OPTIONS)

print("Targets:")
print(solvevol_target)
# Out:
# Targets:
# {'H': 1.24e+21, 'C': 1.24e+20, 'N': 1.5241577798741547e+20, 'S': 1.9051972248426936e+22}

# %% [markdown]
# ### Solve for equilibrium atmospheric partial pressures, etc.

# %%
p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)

print(p_d)

p_bar = {}
for v in volatile_species:
    p_bar[v] = p_d[v+"_bar"]

mubar = 0.0
ptot = 0.0
print("Partial pressures")
for v in solvevol_vols:
    print("    %s : %.3f bar"%(v, p_bar[v]))
    ptot += p_bar[v]
    mubar += p_bar[v]*molar_mass[v]
mubar /= ptot

print("mubar =",mubar)
print("ptot = %.3f bar"%ptot)

m_d = {}
for v in solvevol_vols:
    m_d[v] = p_bar[v]*1.0e5 * 4 * 3.14 * (molar_mass[v]/mubar) * OPTIONS["radius"]**2.0 / OPTIONS["gravity"]

# print(solvevol_atmosphere_mass(p_bar, OPTIONS))

print(" ")
print(m_d)

H_kg = (2*m_d["H2O"]/molar_mass["H2O"] + 2*m_d["H2"]/molar_mass["H2"] + 4*m_d["CH4"]/molar_mass["CH4"]) *molar_mass['H']
C_kg = (m_d["CO2"]/molar_mass["CO2"] + m_d["CO"]/molar_mass["CO"] + m_d["CH4"]/molar_mass["CH4"]) * molar_mass['C']
N_kg = m_d["N2"]
S_kg = m_d["S2"]

print(H_kg, C_kg, N_kg, S_kg)
# Out:
# {'M_atm': 1.379341470514978e+21, 'P_surf': 175.55814654228655, 'H2O_bar': 0.3695996294472581, 'H2O_kg_atm': 2.0850355115166503e+19, 'H2O_kg_liquid': 1.2138554888046544e+21, 'H2O_kg_solid': 0.0, 'H2O_kg_total': 1.234705843919821e+21, 'CO2_bar': 0.0008376852963887342, 'CO2_kg_atm': 1.1544448044428478e+17, 'CO2_kg_liquid': 1458364320985111.5, 'CO2_kg_solid': 0.0, 'CO2_kg_total': 1.1690284476526989e+17, 'H2_bar': 171.3921558153038, 'H2_kg_atm': 1.0819234404739732e+21, 'H2_kg_liquid': 0.0, 'H2_kg_solid': 0.0, 'H2_kg_total': 1.0819234404739732e+21, 'CH4_bar': 1.5384614471551563, 'CH4_kg_atm': 7.727373318535794e+19, 'CH4_kg_liquid': 8.111980121690416e+16, 'CH4_kg_solid': 0.0, 'CH4_kg_total': 7.735485298657485e+19, 'CO_bar': 1.7433018329959629, 'CO_kg_atm': 1.5290673259022307e+20, 'CO_kg_liquid': 1.1088223181917234e+18, 'CO_kg_solid': 0.0, 'CO_kg_total': 1.540155549084148e+20, 'N2_bar': 0.45081094200120747, 'N2_kg_atm': 3.954672149673243e+19, 'N2_kg_liquid': 1.1286905649059865e+20, 'N2_kg_solid': 0.0, 'N2_kg_total': 1.5241577798733106e+20, 'S2_bar': 2.4413422196387454e-07, 'S2_kg_atm': 49003556843643.08, 'S2_kg_liquid': 1.904564956406335e+22, 'S2_kg_solid': 0.0, 'S2_kg_total': 1.9045649613066905e+22, 'SO2_bar': 2.0344752448072794e-07, 'SO2_kg_atm': 40815106277658.74, 'SO2_kg_liquid': 0.0, 'SO2_kg_solid': 0.0, 'SO2_kg_total': 40815106277658.74, 'H2S_bar': 0.06297874250507006, 'H2S_kg_atm': 6.724953354417536e+18, 'H2S_kg_liquid': 0.0, 'H2S_kg_solid': 0.0, 'H2S_kg_total': 6.724953354417536e+18, 'H2O_vmr': 0.0021052832735291662, 'CO2_vmr': 4.7715546836612424e-06, 'H2_vmr': 0.9762700232997772, 'CH4_vmr': 0.00876325865507237, 'CO_vmr': 0.009930053759003745, 'N2_vmr': 0.0025678725304417644, 'S2_vmr': 1.3906174493877452e-09, 'SO2_vmr': 1.1588612006206372e-09, 'H2S_vmr': 0.000358734378013614, 'H_kg_atm': 1.1041431041409565e+21, 'H_kg_liquid': 1.3585689585849822e+20, 'H_kg_solid': 0.0, 'H_kg_total': 1.2399999999994547e+21, 'C_kg_atm': 1.2346338286828795e+20, 'C_kg_liquid': 5.3661713230899725e+17, 'C_kg_solid': 0.0, 'C_kg_total': 1.2400000000059695e+20, 'N_kg_atm': 3.954672149673243e+19, 'N_kg_liquid': 1.1286905649059865e+20, 'N_kg_solid': 0.0, 'N_kg_total': 1.5241577798733106e+20, 'S_kg_atm': 6.322684363580083e+18, 'S_kg_liquid': 1.904564956406335e+22, 'S_kg_solid': 0.0, 'S_kg_total': 1.9051972248426928e+22, 'O_kg_atm': 1.0593935008588864e+20, 'O_kg_liquid': 1.0786345252552713e+21, 'O_kg_solid': 0.0, 'O_kg_total': 1.1845738753411598e+21, 'atm_kg_per_mol': 0.0025090533397004234, 'H2O_mol_atm': 1.1573705829255221e+21, 'H2O_mol_solid': 0.0, 'H2O_mol_liquid': 6.737921857471293e+22, 'H2O_mol_total': 6.853658915763845e+22, 'CO2_mol_atm': 2.6231420232739103e+18, 'CO2_mol_solid': 0.0, 'CO2_mol_liquid': 3.3137112496821436e+16, 'CO2_mol_total': 2.6562791357707315e+18, 'H2_mol_atm': 5.367003196985799e+23, 'H2_mol_solid': 0.0, 'H2_mol_liquid': 0.0, 'H2_mol_total': 5.367003196985799e+23, 'CH4_mol_atm': 4.817564413052241e+21, 'CH4_mol_solid': 0.0, 'CH4_mol_liquid': 5.057344215517716e+18, 'CH4_mol_total': 4.822621757267759e+21, 'CO_mol_atm': 5.459005090689863e+21, 'CO_mol_solid': 0.0, 'CO_mol_liquid': 3.958665898578091e+19, 'CO_mol_total': 5.498591749675644e+21, 'N2_mol_atm': 1.4116770720615558e+21, 'N2_mol_solid': 0.0, 'N2_mol_liquid': 4.029023220196996e+21, 'N2_mol_total': 5.440700292258552e+21, 'S2_mol_atm': 764486066203480.1, 'S2_mol_solid': 0.0, 'S2_mol_liquid': 2.9712401816011464e+23, 'S2_mol_total': 2.971240189246007e+23, 'SO2_mol_atm': 637079047820353.1, 'SO2_mol_solid': 0.0, 'SO2_mol_liquid': 0.0, 'SO2_mol_total': 637079047820353.1, 'H2S_mol_atm': 1.9721270834069022e+20, 'H2S_mol_solid': 0.0, 'H2S_mol_liquid': 0.0, 'H2S_mol_total': 1.9721270834069022e+20, 'H/O_atm': 10.422407757323318, 'H/C_atm': 8.943081571957801, 'H/N_atm': 27.919965609088152, 'H/S_atm': 174.63201397511475, 'O/H_atm': 0.09594711925345165, 'O/C_atm': 0.8580629140779811, 'O/N_atm': 2.67884026984745, 'O/S_atm': 16.75543867034077, 'C/H_atm': 0.11181828008095446, 'C/O_atm': 1.1654157097 ...
# Partial pressures
#     H2O : 0.370 bar
#     CO2 : 0.001 bar
#     N2 : 0.451 bar
#     H2 : 171.392 bar
#     CO : 1.743 bar
#     CH4 : 1.538 bar
#     S2 : 0.000 bar
#     SO2 : 0.000 bar
#     H2S : 0.063 bar
# mubar = 0.0025090533397004225
# ptot = 175.558 bar
#
# {'H2O': 2.0839784873705386e+19, 'CO2': 1.1538595501261182e+17, 'N2': 3.952667299430131e+19, 'H2': 1.0813749513981238e+21, 'CO': 1.5282921539324576e+20, 'CH4': 7.723455869581763e+19, 'S2': 48978714128714.266, 'SO2': 40794414758198.62, 'H2S': 6.721544089665052e+18}
# 1.1031859713790833e+21 1.2340079219482865e+20 3.952667299430131e+19 48978714128714.266

# %% [markdown]
# ### Check results

# %%
H_mol = H_kg / (1.0e-3)
H_oc  = H_mol / (7.69e22 * 2.0)

print("[H] atm = %.4f" % H_oc)
print("C/H atm = %.4f" % (C_kg/H_kg))
# Out:
# [H] atm = 7.1729
# C/H atm = 0.1119

# %% [markdown]
# ### Parameter sweep demo

# %%
plt.close("all")

# parameters
x_arr = np.linspace(-6, 6, 60)
x_key = "fO2_shift_IW"

y_keys = [v+"_vmr" for v in solvevol_vols]
y_keys.extend([v+"_bar" for v in solvevol_vols])

# run model
y_out = {}
for y in y_keys:
    y_out[y] = []
for x in x_arr:
    OPTIONS = deepcopy(BACKUP_options)
    OPTIONS[x_key] = x
    solvevol_target = get_target_from_params(OPTIONS)
    p_d = equilibrium_atmosphere(solvevol_target, OPTIONS)
    for y in y_keys:
        y_out[y].append(p_d[y])


# plot data
fig,ax = plt.subplots(1,1)

for y in y_keys:
    if "_bar" in y:
        ax.plot(x_arr, y_out[y], label=y)
ax.set(xlabel=x_key, ylabel="Partial pressure [Pa]")
ax.legend(ncol=2)
ax.set_yscale("log")
ax.set_ylim(bottom=1e-6)

plt.show()


# write to csv
M = []
header = x_key
M.append(x_arr)
for y in y_keys:
    M.append(y_out[y])
    header += " "+y
M = np.array(M).T
np.savetxt("nogit_solvevol.csv", M, fmt="%.4e", header=header, comments="")
